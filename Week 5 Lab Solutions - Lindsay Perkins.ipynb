# %% [markdown]
# # Week 5 Lab Assignment (200 points)
# MATH 6375
#
# Instructor: Dr. Yang, Dr. Subburaj

# %% [markdown]
# **Note: This assignment is based on the Predicting Bicycle Traffic example disccused in this week's lecture video. Use the solution cell below the questions to record your answers.**

# %% [markdown]
# ## Question 1 (15 points):
# Load the two datasets Fremont Bridge's and Weather data and index them by date using pandas library.

# %%
#Solution
import pandas as pd
fremont_data=pd.read_csv('FremontBridge.csv',index_col='Date', parse_dates=True)
weather_data=pd.read_csv('BicycleWeather.csv',index_col='DATE', parse_dates=True)

# %% [markdown]
# ## Question 2 (15 points):
# Print the first 10 and last 10 records from the two datasets.

# %%
#Solution
fremont_data.head(10)
# Out:
#                      Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
# 2012-10-03 05:00:00                          10.0
# 2012-10-03 06:00:00                          50.0
# 2012-10-03 07:00:00                          95.0
# 2012-10-03 08:00:00                         146.0
# 2012-10-03 09:00:00                         104.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
# 2012-10-03 05:00:00                          21.0
# ...

# %%
fremont_data.tail(10)
# Out:
#                      Fremont Bridge East Sidewalk  \
# Date
# 2018-06-30 14:00:00                          56.0
# 2018-06-30 15:00:00                          64.0
# 2018-06-30 16:00:00                          70.0
# 2018-06-30 17:00:00                          64.0
# 2018-06-30 18:00:00                          45.0
# 2018-06-30 19:00:00                          39.0
# 2018-06-30 20:00:00                          30.0
# 2018-06-30 21:00:00                          21.0
# 2018-06-30 22:00:00                          11.0
# 2018-06-30 23:00:00                          12.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2018-06-30 14:00:00                          63.0
# 2018-06-30 15:00:00                          34.0
# 2018-06-30 16:00:00                          48.0
# 2018-06-30 17:00:00                          39.0
# 2018-06-30 18:00:00                          43.0
# 2018-06-30 19:00:00                          31.0
# ...

# %%
weather_data.head(10)
# Out:
#                       STATION                                STATION_NAME  \
# DATE
# 2012-01-01  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-02  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-03  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-04  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-05  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-06  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-07  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-08  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-09  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2012-01-10  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
#
#             PRCP  SNWD  SNOW  TMAX  TMIN  AWND  WDF2  WDF5  ...  WT17  WT05  \
# DATE                                                        ...
# ...

# %%
weather_data.tail(10)
# Out:
#                       STATION                                STATION_NAME  \
# DATE
# 2015-08-23  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-24  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-25  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-26  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-27  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-28  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-29  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-30  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-08-31  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
# 2015-09-01  GHCND:USW00024233  SEATTLE TACOMA INTERNATIONAL AIRPORT WA US
#
#             PRCP  SNWD  SNOW  TMAX  TMIN  AWND  WDF2  WDF5  ...  WT17  WT05  \
# DATE                                                        ...
# ...

# %% [markdown]
# ## Question 3 (10 points):
# Compute the total daily bicycle traffic, and add this new column called Total to the existing dataframe.

# %%
#Solution
daily=fremont_data.resample('d').sum()
daily['Total']=daily.sum(axis=1)
daily=daily[['Total']]
daily.head()
# Out:
#              Total
# Date
# 2012-10-03  3521.0
# 2012-10-04  3475.0
# 2012-10-05  3148.0
# 2012-10-06  2006.0
# 2012-10-07  2142.0

# %% [markdown]
# ## Question 4 (15 points):
# Print the  number of dimensions, shape (size of each dimension), and size (number of all elements) of the two datasets.

# %%
#Solution
print("Info for Fremont Bridge Data Set")
print("Number of dimensions:", fremont_data.ndim)
print ("Shape (rows,columns):", fremont_data.shape)
print("Size (number of all elements):", fremont_data.size)
print("\n") #skip line
print("Info for Bicycle Weather Data Set")
print("Number of dimensions:", weather_data.ndim)
print ("Shape (rows,columns):", weather_data.shape)
print("Size (number of all elements):", weather_data.size)
# Out:
# Info for Fremont Bridge Data Set
# Number of dimensions: 2
# Shape (rows,columns): (50328, 2)
# Size (number of all elements): 100656
#
#
# Info for Bicycle Weather Data Set
# Number of dimensions: 2
# Shape (rows,columns): (1340, 25)
# Size (number of all elements): 33500

# %% [markdown]
# ## Question 5 (10 points):
# Print the total number of null values found in each column using the Fremont Bridge's data set.

# %%
#Solution
fremont_data.isnull().sum()
# Out:
# Fremont Bridge East Sidewalk    9
# Fremont Bridge West Sidewalk    9
# dtype: int64

# %% [markdown]
# ## Question 6 (10 points):
# Write code to drop the null values in the the Fremont Bridge's data set.

# %%
#Solution
fremont_data.dropna(subset="Fremont Bridge East Sidewalk")
# Out:
#                      Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
# ...                                           ...
# 2018-06-30 19:00:00                          39.0
# 2018-06-30 20:00:00                          30.0
# 2018-06-30 21:00:00                          21.0
# 2018-06-30 22:00:00                          11.0
# 2018-06-30 23:00:00                          12.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
# ...

# %% [markdown]
# ## Question 7 (10 points):
# Write code to display a summary of statistics (count,mean,std,min,etc...) pertaining to the Fremont Bridge's DataFrame columns.

# %%
#Solution
fremont_data.describe()
# Out:
#        Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# count                  50319.000000                  50319.000000
# mean                      56.934399                     52.940678
# std                       82.835585                     68.728939
# min                        0.000000                      0.000000
# 25%                        7.000000                      7.000000
# 50%                       28.000000                     29.000000
# 75%                       69.000000                     70.000000
# max                      717.000000                    698.000000

# %% [markdown]
# ## Question 8 (15 points):
# Resample the Fremont Bridge's data from hourly to weekly, print the first 5 rows of the resampled data, and plot a line graph to visualize the weekly bicycle count.

# %%
#Solution
weekly=fremont_data.resample('w').sum()
weekly['Total']=weekly.sum(axis=1)
weekly=weekly[['Total']]
print(weekly.head())

import matplotlib.pyplot as plt
plt.plot(weekly)
plt.title("Bikers on Fremont Bridge by Week")
plt.xlabel("Year")
plt.ylabel ("Number of Bikers")
# Out:
#               Total
# Date
# 2012-10-07  14292.0
# 2012-10-14  16795.0
# 2012-10-21  15509.0
# 2012-10-28  13437.0
# 2012-11-04  12194.0
# Text(0, 0.5, 'Number of Bikers')

# %% [markdown]
# ## Question 9 (10 points):
# What do you infer from the above plot?
# Describe your observations in 1 or 2 lines.

# %% [raw]
# Answer: This plot shows me that the total number of bikers on Fremont Bridge follows a cyclic pattern, which reflects time of year.  Over the course of five years, 2013 to 2018, a pattern has emerged that has shown higher number of bikers in the middle of the year (warmer months) and lower number of total bikes in the beginnign and end of each year (colder months).

# %% [markdown]
# ## Question 10 (20 points):
# Write a code snippet to visualize the average traffic as a function of the time of day.
# What do you observe from the graph?
#
# Hint: Use groupby function

# %%
#Solution
import numpy as np
import datetime
fremont_data.groupby('Date')

x=fremont_data['Date']
y=fremont_data['Total']
plt.scatter(x,y)
plt.title("Bikes vs. Time of Day")
plt.xlabel("Time of Day")
plt.ylabel ("Total # of Bikes")
plt.scatter
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [raw]
# What do you observe from the graph?
#
# Answer: I could not figure out the "groupby function".  I would think the graph would reveal that the number of bikers has consistent highs and lows throughout the days, peaking before and after work and plummeting late at night.  Looking at time of day vs.bikers over the weekend would be interesting.

# %% [markdown]
# ## Question 11 (20 points):
# Does day-light duration affect bicycle traffic? Let's validate that assumption with scatter plot.  Use the code discussed in the lecture video to calculate the `total` and the `daylight_hrs` column.

# %% [raw]
# Does day-light duration affect bicycle traffic?
#
# Answer: Yes, the first graph is a scatterplot of number of hours of daylight vs. number of bikers.  This graph shows a positive correlation (positive slope) between the two variables.  Additionally, I created graphs of bikers vs time and daylight hours vs time.  The similar shape of the graphs indicates that there is a correlation between the two variables.

# %%
#Solution
import numpy as np
import datetime

def hours_of_daylight(date, axis=23.44, latitude=47.61):
    """Compute the hours of daylight for the given date"""
    days = (date - datetime.datetime(2000, 12, 21)).days
    m = (1. - np.tan(np.radians(latitude))
         * np.tan(np.radians(axis) * np.cos(days * 2 * np.pi / 365.25)))
    return 24. * np.degrees(np.arccos(1 - np.clip(m, 0, 2))) / 180.

daily['daylight_hrs'] = list(map(hours_of_daylight, daily.index))

x=daily['Total']
y=daily['daylight_hrs']
plt.scatter(x,y)
plt.title("Hours of Daylight vs. Number of Bikers (per day) Scatterplot")
plt.xlabel("# of bikers")
plt.ylabel ("# of hours of daylight")


daily[['Total']].plot()
plt.title("Bikers vs. Time")
plt.ylabel("# of Bikers")

daily[['daylight_hrs']].plot()
plt.title("Daylight Hours vs. Time")
plt.ylabel("# of Daylight Hours")
# Out:
# Text(0, 0.5, '# of Daylight Hours')

# %% [markdown]
# ## Question 12 (50 points):
#
# - Fit `daylight_hrs` and the `total` column using the Linear Regression (LR) model.
# - Determine the LR's coefficent. Record your discussion in terms of the coeffieicent calculated.
# - What does extra hours of daylight lead to in terms of the bicyclers?

# %%
#Solution
from sklearn.linear_model import LinearRegression
# Drop any rows with null values
daily.dropna(axis=0, how='any', inplace=True)
column_names = ['daylight_hrs']
X = np.c_[daily[column_names]]
y = np.c_[daily['Total']]

model = LinearRegression(fit_intercept=False)
model.fit(X, y)
daily['predicted'] = model.predict(X)

# %%
daily[['Total', 'predicted']].plot(alpha=0.5);

# %%
r_sq = model.score(X, y)
print ("r^2=", r_sq)
# Out:
# r^2= 0.3417212186898746

# %%
model.coef_
# Out:
# array([[224.91165945]])

# %% [markdown]
# #Interpretation
# When only considering daylight hours, our R^2 value was only 0.34, which is not all that high.
# It indicates that while daylight hours may play an important role in correlating with number of daily bikers, it is not the only factor.
# The model coefficient indicates that for every additional hour of daylight, 224 more people will be biking.
