# %% [markdown]
# # Pandas, Numpy, and Matplotlib Lab Assignment (120 points)
# MATH 6375
#
# Instructors: Dr. Yang, Dr. Subburaj

# %% [markdown]
# In this assignment (Questions 1-7) we will use pandas to examine ozone data.
#
# Ozone data:  Daily readings of the following air quality values for May 1, 1973 (a Tuesday) to September 30, 1973.
#
# - Ozone: Mean ozone in parts per billion from 1300 to 1500 hours at Roosevelt Island
#
# - Solar.R: Solar radiation in Langleys in the frequency band 4000-7700 Angstroms from 0800 to 1200 hours at Central Park
#
# - Wind: Average wind speed in miles per hour at 0700 and 1000 hours at LaGuardia Airport
#
# - Temp: Maximum daily temperature in degrees Fahrenheit at La Guardia Airport.
#
#
# Main Source of data: The data were obtained from the New York State Department of Conservation (ozone data) and
# the National Weather Service (meteorological data).
#
#
# References : Chambers, J. M., Cleveland, W. S., Kleiner, B. and Tukey, P. A. (1983) Graphical Methods for Data Analysis. Belmont, CA: Wadsworth.

# %% [markdown]
# Start by importing pandas, numpy and matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# I have some ozone data in **ozone.csv**. Download the .csv file to the folder your are working.
#
# ## Question 1 (10 points):
#
# Use Pandas' `read_csv` function directly on this file name to open it as a DataFrame. Display the first few rows and the DataFrame info.

# %%
#Solution
ozone_data=pd.read_csv('ozone.csv')
ozone_data
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 148   30.0    193.0   6.9    70      9   26
# 149    NaN    145.0  13.2    77      9   27
# 150   14.0    191.0  14.3    75      9   28
# 151   18.0    131.0   8.0    76      9   29
# 152   20.0    223.0  11.5    68      9   30
#
# [153 rows x 6 columns]

# %% [markdown]
# ## Question 2 (10 points):
#
# Use `describe` to get the basic statistics of all the columns. Note the highest and lowest temp values in the databse.

# %%
#Solution
ozone_data.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  116.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     32.987885   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     18.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     31.500000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     63.250000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
#Solution part 2
Temp_min = ozone_data["Temp"].min()
print("Temp_min=",Temp_min)

Temp_max = ozone_data["Temp"].max()
print("Temp_max=",Temp_max)
# Out:
# Temp_min= 56
# Temp_max= 97

# %% [markdown]
# ## Question 3 (10 points):
#
# Execute this statement to assign a correlation matrix to the variable ozoneCorr: `ozoneCorr = data_ozone.corr()`
#
# This matrix shows correlations between all the pairwise combinations of columns in the DataFrame.
# Recall that correlation values range from -1 to 1, and those that have greater magnitude (whether positive or negative) indicate a stronger relationships between two variables. That is, values closer to 1 (-1) indicate a high probability that if the value of one variable is high that the value of the other variable will be high (low).
#
# Observe which pair of variables/columns have the greatest magnitude (absolute value) of correlation. (Ignore that correlation values of 1 between each of the variables and themselves.)
# Also, observe which two variables have the lowest correlation (closest to zero).

# %%
#Solution
ozoneCorr=ozone_data.corr()
ozoneCorr

#The greatest correlation is between Ozone and Temperature with a value of 0.698.  The lowerst correlation is between Month and Day.
# Out:
#             Ozone   Solar.R      Wind      Temp     Month       Day
# Ozone    1.000000  0.348342 -0.601547  0.698360  0.164519 -0.013226
# Solar.R  0.348342  1.000000 -0.056792  0.275840 -0.075301 -0.150275
# Wind    -0.601547 -0.056792  1.000000 -0.457988 -0.178293  0.027181
# Temp     0.698360  0.275840 -0.457988  1.000000  0.420947 -0.130593
# Month    0.164519 -0.075301 -0.178293  0.420947  1.000000 -0.007962
# Day     -0.013226 -0.150275  0.027181 -0.130593 -0.007962  1.000000

# %% [markdown]
# ## Question 4 (10 points):
#
# Use matplotlib to plot a scatterplot between the Ozone and Wind values to study the relationship between the two by specifying the appropriate DataFrame columns to matplotlib.
#
# Give the axes appropriate captions and the graphs appropriate titles.
#
# Place useful comments in your code so that you would remember your programming logic if you were to revisit this code later.

# %%
#Solution

#importing Mathplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

#defining variables and preparing data
Day=ozone_data["Day"]
Ozone=ozone_data["Ozone"]
Wind=ozone_data["Wind"]
x=['Day']
y=['Ozone']
z= ['Wind']

#Plot 1 shows relation between ozone and wind.  Graph shows a negative correlation.
dataFrame = pd.DataFrame(data=ozone_data, columns=['Ozone','Wind']) #defining dataframe
dataFrame.plot.scatter(y,z) #plotting dataframe
plt.title("Ozone Concentration vs. Wind") #chaning title
plt.xlabel("Ozone Concentration") #changing x axis label
plt.ylabel("Wind Speed") #changing y axis label
plt.show #showing as output

#Plot 2 shows Day vs. Ozone values, which I think would be interesting to see.
dataFrame = pd.DataFrame(data=ozone_data, columns=['Day','Ozone'])
dataFrame.plot.scatter(x,y)
plt.title("Day vs. Ozone Concentration")
plt.ylabel("Ozone Concentration")
plt.show

#Plot 3 shows Day vs. Wind values, which I also thought could be interesting to see
dataFrame = pd.DataFrame(data=ozone_data, columns=['Day','Wind'])
dataFrame.plot.scatter(x,z)
plt.title("Day vs. Wind")
plt.ylabel("Wind Speed")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Question 5 (10 points):
#
# What happens when we use pairplot command with the entire dataset without selecting any particular columns?
#
# Hint: Look into Seaborn visualization library

# %%
# Solution
import seaborn
df=seaborn.pairplot(ozone_data)
df
#woah

# %% [markdown]
# ## Question 6 (10 points):
#
# Use matplotlib to plot a bar chart to determin the Ozone Concerntration in Air.
#
# Give the axes appropriate captions and the graphs appropriate titles.
#
# Place useful comments in your code so that you would remember your programming logic if you were to revisit this code later.

# %%
#Solution
# Vertical bar plot

#I was a little confused about what you were looking for here

#importing Mathplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

#defining variables and preparing data
Month=ozone_data["Month"]
Ozone=ozone_data["Ozone"]
x=['Month']
y=['Ozone']

#Plot
dataFrame = pd.DataFrame(data=ozone_data, columns=['Month','Ozone']) #defining dataframe
dataFrame.plot.scatter(x,y) #plotting dataframe
plt.title("Ozone Concentration vs. Month") #chaning title
plt.xlabel("Month") #changing x axis label
plt.ylabel("Ozone Concentration") #changing y axis label
plt.xlim(0, 12)
plt.ylim(0, 175)
plt.show #showing as output
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Question 7 (10 points):
#
# Use matplotlib to plot a histogram for Solar.R.
#
# Give the axes appropriate captions and the graphs appropriate titles.
#
# Place useful comments in your code so that you would remember your programming logic if you were to revisit this code later.
#
# A histogram is quite similar to a bar chart except that it groups values into continuous ranges. A histogram represents the frequencies of values of a variable bucketed into ranges.

# %%
#Solution

import numpy as np
import matplotlib.pyplot as plt

data = ozone_data["Solar.R"] #define data
plt.hist(data) #create histogram
plt.title("Solar Radiation Histogram") #change title
plt.xlabel("Solar Radiation Concentration") #change axis label
plt.ylabel("Frequency") #changeaxis label
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Question 8 (10 points):
#
# Following code snippet will generate different set of random numbers whenever executed. Can you introduce a statement at `------` such that the random function generates the same set of random numbers?

# %%
#Solution
import numpy as np
np.random.seed(0)
random_integers = np.random.randint(1,100, size=(4, 3))
random_integers
# Out:
# array([[45, 48, 65],
#        [68, 68, 10],
#        [84, 22, 37],
#        [88, 71, 89]])

# %% [markdown]
# ## Question 9 (10 points):
#
# Slice the following numpy array to get an output of
#
#     array([[20, 30],
#            [50, 60]])

# %%
#Solution
my_arr = np.array([[10, 20, 30], [40, 50, 60]])
my_slice=my_arr[0:2,1:3]
my_slice
# Out:
# array([[20, 30],
#        [50, 60]])

# %% [markdown]
# ## Question 10 (10 points):
#
# Modify the following array to get the following output:
#
#     array([[ 1,  2,  0],
#            [ 3,  6,  0],
#            [ 5, 10,  0]])

# %%
#Solution
np.array([(i,i*2,0) for i in range(1,6,2)])
# Out:
# array([[ 1,  2,  0],
#        [ 3,  6,  0],
#        [ 5, 10,  0]])

# %% [markdown]
# ## Question 11 (10 points):
#
# Create a 4x4 array of normally distributed random values with mean 0 and standard deviation 1

# %%
#Solution
np.random.normal(0,1,(4,4))
# Out:
# array([[-0.30190059,  0.7613829 , -0.64408805, -1.72680187],
#        [ 0.22661455,  1.71978228, -1.76204669, -0.28895997],
#        [ 0.54963858, -1.13114405,  2.35787491, -0.12430064],
#        [ 1.05765063, -1.534186  , -0.87102437,  0.27763476]])

# %% [markdown]
# ## Question 12 (10 points):
#
# Use fancy indexing to get an output of
#
#     array([2. , 5. , 1.5 , 3.])

# %%
b = np.array([(1.5,2,3), (4,5,6)], dtype = float)
print(b)
b[[0,1,0,0],[1,1,0,2]]
# Out:
# [[1.5 2.  3. ]
#  [4.  5.  6. ]]
# array([2. , 5. , 1.5, 3. ])
